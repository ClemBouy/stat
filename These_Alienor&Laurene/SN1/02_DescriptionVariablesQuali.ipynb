# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv('data.csv')

# %%
categorical_columns = ['tag', 'FS', 'PE', 'RC', 'specialty', 'step_5', 'step_2', 'ecn_item', 'skill', 'ped_ambu', 'order_1', 'order_2', 'step_PEC_TTT', 'step_diag', 'step_autre']

for col in categorical_columns:
    display(data[col].describe())
    plt.figure(figsize=(20, 10))
    proportions = data[col].value_counts(normalize=True) * 100
    values = data[col].value_counts()
    # display(proportions, values)
    df = pd.DataFrame({ "proportions": proportions, "valeurs": values })
    display(df)
    # proportions = proportions.head(15)
    # print(proportions)
    sns.barplot(x=proportions.index, y=proportions.values)
    plt.title(f"Diagramme en barres pour la variable {col} (proportions)")
    plt.ylabel('Proportion (%)')
    plt.xticks(rotation=90)
    plt.show()
# Out:
# count       603
# unique        2
# top       SN1-1
# freq        593
# Name: tag, dtype: object
#        proportions  valeurs
# tag
# SN1-1    98.341625      593
# SN1-2     1.658375       10
# count      603
# unique      11
# top       FS02
# freq       142
# Name: FS, dtype: object
#       proportions  valeurs
# FS
# FS02    23.548922      142
# FS01    23.217247      140
# FS04    13.432836       81
# FS03     9.286899       56
# FS09     8.789386       53
# FS05     5.804312       35
# FS08     5.306799       32
# FS10     3.648425       22
# FS07     3.482587       21
# FS11     1.824212       11
# FS06     1.658375       10
# count      603
# unique      10
# top       PE01
# freq       144
# Name: PE, dtype: object
#       proportions  valeurs
# PE
# PE01    23.880597      144
# PE02    12.271973       74
# PE08    12.106136       73
# PE04     9.618574       58
# PE05     9.286899       56
# PE09     8.623549       52
# PE10     7.296849       44
# PE06     6.799337       41
# PE07     5.804312       35
# PE03     4.311774       26
# count                          472
# unique                         119
# top       PROCÉDURE ADMINISTRATIVE
# freq                            60
# Name: RC, dtype: object
#                                                 proportions  valeurs
# RC
# PROCÉDURE ADMINISTRATIVE                          12.711864       60
# DÉPISTAGE ET PRÉVENTION                           10.593220       50
# VACCINATION                                       10.169492       48
# HTA                                                4.661017       22
# DYSLIPIDÉMIE                                       2.966102       14
# ...                                                     ...      ...
# HÉMATURIE                                          0.211864        1
# PRURIT GÉNÉRALISÉ                                  0.211864        1
# COMPORTEMENT (TROUBLES)                            0.211864        1
# INSUFFISANCE RÉNALE - MALADIE RENALE CHRONIQUE     0.211864        1
# CRAMPE MUSCULAIRE                                  0.211864        1
#
# [119 rows x 2 columns]
# count                                601
# unique                                20
# top       Ethique/Communication/Relation
# freq                                 124
# Name: specialty, dtype: object
#                                        proportions  valeurs
# specialty
# Ethique/Communication/Relation           20.632280      124
# Pédiatrie                                 9.650582       58
# Cardiologie                               9.151414       55
# Santé publique (Administratif/Social)     8.985025       54
# Psychiatrie                               6.489185       39
# Rhumatologie                              5.657238       34
# Gynécologie                               5.158070       31
# Pneumologie                               4.991681       30
# Endocrinologie                            4.658902       28
# Dermatologie                              4.159734       25
# Infectiologie                             3.660566       22
# Gastroentérologie                         3.494176       21
# ORL                                       3.327787       20
# Neurologie                                3.161398       19
# Urologie                                  2.828619       17
# Orthopédie                                2.163062       13
# Néphrologie                               0.665557        4
# Ophtalmologie                             0.499168        3
# Médecine Interne - Immuno                 0.332779        2
# Hématologie                               0.332779        2
# count         601
# unique          6
# top       PEC-ttt
# freq          283
# Name: step_5, dtype: object
#                                 proportions  valeurs
# step_5
# PEC-ttt                           47.088186      283
# Ethique-Communication-Relation    21.630616      130
# Diagnostic                        15.474210       93
# Administratif-Social               9.983361       60
# Diag+PEC                           5.324459       32
# Prévention-Education               0.499168        3
# count         601
# unique          4
# top       PEC-ttt
# freq          283
# Name: step_2, dtype: object
#             proportions  valeurs
# step_2
# PEC-ttt       47.088186      283
# Autre         32.279534      194
# Diagnostic    15.307820       92
# Diag+PEC       5.324459       32
# count        598
# unique       135
# top       Item 1
# freq         122
# Name: ecn_item, dtype: object
#           proportions  valeurs
# ecn_item
# Item 1      20.401338      122
# Item 146     7.692308       46
# Item 224     3.511706       21
# Item 290     2.341137       14
# Item 128     2.173913       13
# ...               ...      ...
# Item 264     0.167224        1
# Item 241     0.167224        1
# Item 6       0.167224        1
# Item 71      0.167224        1
# Item 217     0.167224        1
#
# [135 rows x 2 columns]
# count     600
# unique      6
# top        C4
# freq      169
# Name: skill, dtype: object
#        proportions  valeurs
# skill
# C4       28.166667      169
# C3       22.833333      137
# C1       20.000000      120
# C2       15.000000       90
# C5       10.500000       63
# C6        3.500000       21
# count     603
# unique      2
# top       non
# freq      494
# Name: ped_ambu, dtype: object
#           proportions  valeurs
# ped_ambu
# non         81.923715      494
# oui         18.076285      109
# count                    603
# unique                     2
# top       Urgences avant SN1
# freq                     353
# Name: order_1, dtype: object
#                     proportions  valeurs
# order_1
# Urgences avant SN1     58.54063      353
# SN1 avant Urgences     41.45937      250
# count                      603
# unique                       3
# top       SN2 avant Pôle femme
# freq                       321
# Name: order_2, dtype: object
#                                 proportions  valeurs
# order_2
# SN2 avant Pôle femme              53.233831      321
# Pôle femme avant SN2              35.157546      212
# Aucun des deux n'a été réalisé    11.608624       70
# count    603.000000
# mean       0.522388
# std        0.499913
# min        0.000000
# 25%        0.000000
# 50%        1.000000
# 75%        1.000000
# max        1.000000
# Name: step_PEC_TTT, dtype: float64
#               proportions  valeurs
# step_PEC_TTT
# 1               52.238806      315
# 0               47.761194      288
# count    603.000000
# mean       0.205638
# std        0.404503
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000
# Name: step_diag, dtype: float64
#            proportions  valeurs
# step_diag
# 0            79.436153      479
# 1            20.563847      124
# count    603.000000
# mean       0.321725
# std        0.467526
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000
# Name: step_autre, dtype: float64
#             proportions  valeurs
# step_autre
# 0             67.827529      409
# 1             32.172471      194
