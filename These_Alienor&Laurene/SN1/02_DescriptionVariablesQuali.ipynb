# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv('data.csv')

# %%
categorical_columns = ['tag', 'FS', 'PE', 'RC', 'specialty', 'step_5', 'step_2', 'ecn_item', 'skill', 'ped_ambu', 'order_1', 'order_2', 'step_PEC_TTT', 'step_diag', 'step_autre']

for col in categorical_columns:
    display(data[col].describe())
    plt.figure(figsize=(20, 10))
    proportions = data[col].value_counts(normalize=True) * 100
    # proportions = proportions.head(15)
    print(proportions)
    sns.barplot(x=proportions.index, y=proportions.values)
    plt.title(f"Diagramme en barres pour la variable {col} (proportions)")
    plt.ylabel('Proportion (%)')
    plt.xticks(rotation=90)
    plt.show()
# Out:
# count       603
# unique        2
# top       SN1-1
# freq        593
# Name: tag, dtype: object
# tag
# SN1-1    98.341625
# SN1-2     1.658375
# Name: proportion, dtype: float64
# count      603
# unique      11
# top       FS02
# freq       142
# Name: FS, dtype: object
# FS
# FS02    23.548922
# FS01    23.217247
# FS04    13.432836
# FS03     9.286899
# FS09     8.789386
# FS05     5.804312
# FS08     5.306799
# FS10     3.648425
# FS07     3.482587
# FS11     1.824212
# FS06     1.658375
# Name: proportion, dtype: float64
# count      603
# unique      10
# top       PE01
# freq       144
# Name: PE, dtype: object
# PE
# PE01    23.880597
# PE02    12.271973
# PE08    12.106136
# PE04     9.618574
# PE05     9.286899
# PE09     8.623549
# PE10     7.296849
# PE06     6.799337
# PE07     5.804312
# PE03     4.311774
# Name: proportion, dtype: float64
# count                          472
# unique                         119
# top       PROCÉDURE ADMINISTRATIVE
# freq                            60
# Name: RC, dtype: object
# RC
# PROCÉDURE ADMINISTRATIVE                          12.711864
# DÉPISTAGE ET PRÉVENTION                           10.593220
# VACCINATION                                       10.169492
# HTA                                                4.661017
# DYSLIPIDÉMIE                                       2.966102
#                                                     ...
# HÉMATURIE                                          0.211864
# PRURIT GÉNÉRALISÉ                                  0.211864
# COMPORTEMENT (TROUBLES)                            0.211864
# INSUFFISANCE RÉNALE - MALADIE RENALE CHRONIQUE     0.211864
# CRAMPE MUSCULAIRE                                  0.211864
# Name: proportion, Length: 119, dtype: float64
# count                                601
# unique                                20
# top       Ethique/Communication/Relation
# freq                                 124
# Name: specialty, dtype: object
# specialty
# Ethique/Communication/Relation           20.632280
# Pédiatrie                                 9.650582
# Cardiologie                               9.151414
# Santé publique (Administratif/Social)     8.985025
# Psychiatrie                               6.489185
# Rhumatologie                              5.657238
# Gynécologie                               5.158070
# Pneumologie                               4.991681
# Endocrinologie                            4.658902
# Dermatologie                              4.159734
# Infectiologie                             3.660566
# Gastroentérologie                         3.494176
# ORL                                       3.327787
# Neurologie                                3.161398
# Urologie                                  2.828619
# Orthopédie                                2.163062
# Néphrologie                               0.665557
# Ophtalmologie                             0.499168
# Médecine Interne - Immuno                 0.332779
# Hématologie                               0.332779
# Name: proportion, dtype: float64
# count         601
# unique          6
# top       PEC-ttt
# freq          283
# Name: step_5, dtype: object
# step_5
# PEC-ttt                           47.088186
# Ethique-Communication-Relation    21.630616
# Diagnostic                        15.474210
# Administratif-Social               9.983361
# Diag+PEC                           5.324459
# Prévention-Education               0.499168
# Name: proportion, dtype: float64
# count         601
# unique          4
# top       PEC-ttt
# freq          283
# Name: step_2, dtype: object
# step_2
# PEC-ttt       47.088186
# Autre         32.279534
# Diagnostic    15.307820
# Diag+PEC       5.324459
# Name: proportion, dtype: float64
# count        598
# unique       135
# top       Item 1
# freq         122
# Name: ecn_item, dtype: object
# ecn_item
# Item 1      20.401338
# Item 146     7.692308
# Item 224     3.511706
# Item 290     2.341137
# Item 128     2.173913
#               ...
# Item 264     0.167224
# Item 241     0.167224
# Item 6       0.167224
# Item 71      0.167224
# Item 217     0.167224
# Name: proportion, Length: 135, dtype: float64
# count     600
# unique      6
# top        C4
# freq      169
# Name: skill, dtype: object
# skill
# C4    28.166667
# C3    22.833333
# C1    20.000000
# C2    15.000000
# C5    10.500000
# C6     3.500000
# Name: proportion, dtype: float64
# count     603
# unique      2
# top       non
# freq      494
# Name: ped_ambu, dtype: object
# ped_ambu
# non    81.923715
# oui    18.076285
# Name: proportion, dtype: float64
# count                    603
# unique                     2
# top       Urgences avant SN1
# freq                     353
# Name: order_1, dtype: object
# order_1
# Urgences avant SN1    58.54063
# SN1 avant Urgences    41.45937
# Name: proportion, dtype: float64
# count                      603
# unique                       3
# top       SN2 avant Pôle femme
# freq                       321
# Name: order_2, dtype: object
# order_2
# SN2 avant Pôle femme              53.233831
# Pôle femme avant SN2              35.157546
# Aucun des deux n'a été réalisé    11.608624
# Name: proportion, dtype: float64
# count    603.000000
# mean       0.522388
# std        0.499913
# min        0.000000
# 25%        0.000000
# 50%        1.000000
# 75%        1.000000
# max        1.000000
# Name: step_PEC_TTT, dtype: float64
# step_PEC_TTT
# 1    52.238806
# 0    47.761194
# Name: proportion, dtype: float64
# count    603.000000
# mean       0.205638
# std        0.404503
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000
# Name: step_diag, dtype: float64
# step_diag
# 0    79.436153
# 1    20.563847
# Name: proportion, dtype: float64
# count    603.000000
# mean       0.321725
# std        0.467526
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000
# Name: step_autre, dtype: float64
# step_autre
# 0    67.827529
# 1    32.172471
# Name: proportion, dtype: float64
