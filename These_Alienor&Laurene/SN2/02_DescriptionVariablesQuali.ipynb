# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv('data.csv')

# %%
categorical_columns = ['tag', 'FS', 'PE', 'RC', 'specialty', 'step_5', 'step_2', 'ecn_item', 'skill', 'ped_ambu', 'order_1', 'order_2', 'step_PEC_TTT', 'step_diag', 'step_autre']

for col in categorical_columns:
    display(data[col].describe())
    plt.figure(figsize=(20, 10))
    proportions = data[col].value_counts(normalize=True) * 100
    # proportions = proportions.head(15)
    print(proportions)
    sns.barplot(x=proportions.index, y=proportions.values)
    plt.title(f"Diagramme en barres pour la variable {col} (proportions)")
    plt.ylabel('Proportion (%)')
    plt.xticks(rotation=90)
    plt.show()
# Out:
# count       864
# unique        3
# top       SN1-1
# freq        593
# Name: tag, dtype: object
# tag
# SN1-1    68.634259
# SN2-1    30.208333
# SN1-2     1.157407
# Name: proportion, dtype: float64
# count      864
# unique      11
# top       FS02
# freq       194
# Name: FS, dtype: object
# FS
# FS02    22.453704
# FS01    21.412037
# FS04    12.037037
# FS09     9.143519
# FS03     8.912037
# FS08     8.217593
# FS05     6.018519
# FS10     4.050926
# FS07     3.240741
# FS11     2.430556
# FS06     2.083333
# Name: proportion, dtype: float64
# count      864
# unique      10
# top       PE01
# freq       184
# Name: PE, dtype: object
# PE
# PE01    21.296296
# PE02    12.731481
# PE08    11.111111
# PE05    10.300926
# PE04     9.375000
# PE10     8.912037
# PE09     8.680556
# PE06     7.638889
# PE07     5.439815
# PE03     4.513889
# Name: proportion, dtype: float64
# count                          688
# unique                         156
# top       PROCÉDURE ADMINISTRATIVE
# freq                           107
# Name: RC, dtype: object
# RC
# PROCÉDURE ADMINISTRATIVE    15.552326
# DÉPISTAGE ET PRÉVENTION      8.866279
# VACCINATION                  8.720930
# HTA                          4.069767
# DÉPRESSION                   3.488372
#                               ...
# EMBOLIE PULMONAIRE           0.145349
# OTITE EXTERNE                0.145349
# LUXATION                     0.145349
# ABCÈS SUPERFICIEL            0.145349
# ÉNURÉSIE PSYCHOGÈNE          0.145349
# Name: proportion, Length: 156, dtype: float64
# count                                860
# unique                                20
# top       Ethique/Communication/Relation
# freq                                 168
# Name: specialty, dtype: object
# specialty
# Ethique/Communication/Relation           19.534884
# Santé publique (Administratif/Social)    11.627907
# Pédiatrie                                 8.837209
# Cardiologie                               8.139535
# Psychiatrie                               7.674419
# Pneumologie                               5.232558
# Rhumatologie                              5.000000
# Gynécologie                               4.767442
# Endocrinologie                            4.418605
# Dermatologie                              4.302326
# ORL                                       3.720930
# Infectiologie                             3.255814
# Neurologie                                3.139535
# Gastroentérologie                         3.023256
# Urologie                                  2.674419
# Orthopédie                                2.558140
# Médecine Interne - Immuno                 0.697674
# Ophtalmologie                             0.465116
# Néphrologie                               0.465116
# Hématologie                               0.465116
# Name: proportion, dtype: float64
# count         861
# unique          6
# top       PEC-ttt
# freq          391
# Name: step_5, dtype: object
# step_5
# PEC-ttt                           45.412311
# Ethique-Communication-Relation    20.325203
# Diagnostic                        14.866434
# Administratif-Social              12.427410
# Diag+PEC                           6.620209
# Prévention-Education               0.348432
# Name: proportion, dtype: float64
# count         861
# unique          4
# top       PEC-ttt
# freq          391
# Name: step_2, dtype: object
# step_2
# PEC-ttt       45.412311
# Autre         33.217189
# Diagnostic    14.750290
# Diag+PEC       6.620209
# Name: proportion, dtype: float64
# count        855
# unique       159
# top       Item 1
# freq         161
# Name: ecn_item, dtype: object
# ecn_item
# Item 1      18.830409
# Item 146     6.432749
# Item 224     3.157895
# Item 19      2.222222
# Item 290     2.222222
#               ...
# Item 4       0.116959
# Item 39      0.116959
# Item 212     0.116959
# Item 264     0.116959
# Item 51      0.116959
# Name: proportion, Length: 159, dtype: float64
# count     860
# unique      6
# top        C4
# freq      249
# Name: skill, dtype: object
# skill
# C4    28.953488
# C3    21.279070
# C1    18.720930
# C2    13.488372
# C5    12.558140
# C6     5.000000
# Name: proportion, dtype: float64
# count     864
# unique      2
# top       non
# freq      686
# Name: ped_ambu, dtype: object
# ped_ambu
# non    79.398148
# oui    20.601852
# Name: proportion, dtype: float64
# count                    864
# unique                     2
# top       Urgences avant SN1
# freq                     493
# Name: order_1, dtype: object
# order_1
# Urgences avant SN1    57.060185
# SN1 avant Urgences    42.939815
# Name: proportion, dtype: float64
# count                      864
# unique                       3
# top       SN2 avant Pôle femme
# freq                       581
# Name: order_2, dtype: object
# order_2
# SN2 avant Pôle femme              67.245370
# Pôle femme avant SN2              24.652778
# Aucun des deux n'a été réalisé     8.101852
# Name: proportion, dtype: float64
# count    864.000000
# mean       0.518519
# std        0.499946
# min        0.000000
# 25%        0.000000
# 50%        1.000000
# 75%        1.000000
# max        1.000000
# Name: step_PEC_TTT, dtype: float64
# step_PEC_TTT
# 1    51.851852
# 0    48.148148
# Name: proportion, dtype: float64
# count    864.000000
# mean       0.212963
# std        0.409639
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000
# Name: step_diag, dtype: float64
# step_diag
# 0    78.703704
# 1    21.296296
# Name: proportion, dtype: float64
# count    864.000000
# mean       0.331019
# std        0.470852
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000
# Name: step_autre, dtype: float64
# step_autre
# 0    66.898148
# 1    33.101852
# Name: proportion, dtype: float64
