# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv('data.csv')

# %%
categorical_columns = ['tag', 'FS', 'PE', 'RC', 'specialty', 'step_5', 'step_2', 'ecn_item', 'skill', 'ped_ambu', 'order_1', 'order_2', 'step_PEC_TTT', 'step_diag', 'step_autre']

for col in categorical_columns:
    display(data[col].describe())
    plt.figure(figsize=(20, 10))
    proportions = data[col].value_counts(normalize=True) * 100
    # proportions = proportions.head(15)
    print(proportions)
    sns.barplot(x=proportions.index, y=proportions.values)
    plt.title(f"Diagramme en barres pour la variable {col} (proportions)")
    plt.ylabel('Proportion (%)')
    plt.xticks(rotation=90)
    plt.show()
# Out:
# count       261
# unique        1
# top       SN2-1
# freq        261
# Name: tag, dtype: object
# tag
# SN2-1    100.0
# Name: proportion, dtype: float64
# count      261
# unique      11
# top       FS02
# freq        52
# Name: FS, dtype: object
# FS
# FS02    19.923372
# FS01    17.241379
# FS08    14.942529
# FS09     9.961686
# FS04     8.812261
# FS03     8.045977
# FS05     6.513410
# FS10     4.980843
# FS11     3.831418
# FS06     3.065134
# FS07     2.681992
# Name: proportion, dtype: float64
# count      261
# unique      10
# top       PE01
# freq        40
# Name: PE, dtype: object
# PE
# PE01    15.325670
# PE02    13.793103
# PE05    12.643678
# PE10    12.643678
# PE06     9.578544
# PE08     8.812261
# PE04     8.812261
# PE09     8.812261
# PE03     4.980843
# PE07     4.597701
# Name: proportion, dtype: float64
# count                          216
# unique                          85
# top       PROCÉDURE ADMINISTRATIVE
# freq                            47
# Name: RC, dtype: object
# RC
# PROCÉDURE ADMINISTRATIVE                             21.759259
# DÉPRESSION                                            6.018519
# VACCINATION                                           5.555556
# DÉPISTAGE ET PRÉVENTION                               5.092593
# IATROGÈNE - EFFET INDÉSIRABLE D’UNE THÉRAPEUTIQUE     3.240741
#                                                        ...
# CÉRUMEN (BOUCHON DE)                                  0.462963
# ASTHÉNIE - FATIGUE                                    0.462963
# SEXUELLE (DYSFONCTION)                                0.462963
# BRONCHITE AIGUË                                       0.462963
# HERPÈS                                                0.462963
# Name: proportion, Length: 85, dtype: float64
# count                                       259
# unique                                       19
# top       Santé publique (Administratif/Social)
# freq                                         46
# Name: specialty, dtype: object
# specialty
# Santé publique (Administratif/Social)    17.760618
# Ethique/Communication/Relation           16.988417
# Psychiatrie                              10.424710
# Pédiatrie                                 6.949807
# Cardiologie                               5.791506
# Pneumologie                               5.791506
# ORL                                       4.633205
# Dermatologie                              4.633205
# Gynécologie                               3.861004
# Endocrinologie                            3.861004
# Rhumatologie                              3.474903
# Orthopédie                                3.474903
# Neurologie                                3.088803
# Infectiologie                             2.316602
# Urologie                                  2.316602
# Gastroentérologie                         1.930502
# Médecine Interne - Immuno                 1.544402
# Hématologie                               0.772201
# Ophtalmologie                             0.386100
# Name: proportion, dtype: float64
# count         260
# unique          5
# top       PEC-ttt
# freq          108
# Name: step_5, dtype: object
# step_5
# PEC-ttt                           41.538462
# Administratif-Social              18.076923
# Ethique-Communication-Relation    17.307692
# Diagnostic                        13.461538
# Diag+PEC                           9.615385
# Name: proportion, dtype: float64
# count         260
# unique          4
# top       PEC-ttt
# freq          108
# Name: step_2, dtype: object
# step_2
# PEC-ttt       41.538462
# Autre         35.384615
# Diagnostic    13.461538
# Diag+PEC       9.615385
# Name: proportion, dtype: float64
# count        257
# unique        98
# top       Item 1
# freq          39
# Name: ecn_item, dtype: object
# ecn_item
# Item 1      15.175097
# Item 19      4.669261
# Item 146     3.501946
# Item 74      2.723735
# Item 204     2.723735
#               ...
# Item 124     0.389105
# Item 219     0.389105
# Item 265     0.389105
# Item 248     0.389105
# Item 95      0.389105
# Name: proportion, Length: 98, dtype: float64
# count     260
# unique      6
# top        C4
# freq       80
# Name: skill, dtype: object
# skill
# C4    30.769231
# C3    17.692308
# C5    17.307692
# C1    15.769231
# C2    10.000000
# C6     8.461538
# Name: proportion, dtype: float64
# count     261
# unique      2
# top       non
# freq      192
# Name: ped_ambu, dtype: object
# ped_ambu
# non    73.563218
# oui    26.436782
# Name: proportion, dtype: float64
# count                    261
# unique                     2
# top       Urgences avant SN1
# freq                     140
# Name: order_1, dtype: object
# order_1
# Urgences avant SN1    53.639847
# SN1 avant Urgences    46.360153
# Name: proportion, dtype: float64
# count                      261
# unique                       2
# top       SN2 avant Pôle femme
# freq                       260
# Name: order_2, dtype: object
# order_2
# SN2 avant Pôle femme    99.616858
# Pôle femme avant SN2     0.383142
# Name: proportion, dtype: float64
# count    261.000000
# mean       0.509579
# std        0.500869
# min        0.000000
# 25%        0.000000
# 50%        1.000000
# 75%        1.000000
# max        1.000000
# Name: step_PEC_TTT, dtype: float64
# step_PEC_TTT
# 1    50.957854
# 0    49.042146
# Name: proportion, dtype: float64
# count    261.000000
# mean       0.229885
# std        0.421567
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000
# Name: step_diag, dtype: float64
# step_diag
# 0    77.011494
# 1    22.988506
# Name: proportion, dtype: float64
# count    261.000000
# mean       0.352490
# std        0.478664
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000
# Name: step_autre, dtype: float64
# step_autre
# 0    64.750958
# 1    35.249042
# Name: proportion, dtype: float64
